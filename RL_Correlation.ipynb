# %% [markdown]
# <a href="https://colab.research.google.com/github/aman29gupta/Reinforcement-Learning/blob/main/RL_Correlation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4])
y=np.array([4,5,6,7])
r=np.corrcoef(x,y)
print(r)
print(plt.scatter(x,y))
# Out:
# [[1. 1.]
#  [1. 1.]]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4])
y=np.array([4,3,2,1])
r=np.corrcoef(x,y)
print(r)
print(plt.scatter(x,y))
# Out:
# [[ 1. -1.]
#  [-1.  1.]]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(25)
r=np.corrcoef(x)
print(r)
print(plt.scatter(x))
# Out:
# 1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9b95e82f4749> in <cell line: 6>()
#       4 r=np.corrcoef(x)
#       5 print(r)
# ----> 6 print(plt.scatter(x))
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randint(0,50,100)
y=np.random.randint(0,50,100)
plt.scatter(x,y)
plt.show()

# %%
import pandas as pd
df = {

}

# %%
df = pd.DataFrame(np.random.rand(50, 4))
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='0', ylabel='0'>, <Axes: xlabel='1', ylabel='0'>,
#         <Axes: xlabel='2', ylabel='0'>, <Axes: xlabel='3', ylabel='0'>],
#        [<Axes: xlabel='0', ylabel='1'>, <Axes: xlabel='1', ylabel='1'>,
#         <Axes: xlabel='2', ylabel='1'>, <Axes: xlabel='3', ylabel='1'>],
#        [<Axes: xlabel='0', ylabel='2'>, <Axes: xlabel='1', ylabel='2'>,
#         <Axes: xlabel='2', ylabel='2'>, <Axes: xlabel='3', ylabel='2'>],
#        [<Axes: xlabel='0', ylabel='3'>, <Axes: xlabel='1', ylabel='3'>,
#         <Axes: xlabel='2', ylabel='3'>, <Axes: xlabel='3', ylabel='3'>]],
#       dtype=object)
